# %% [markdown]
# # GAN To Generate Fake Data

# %%
import pandas as pd
import numpy as np
import torch
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer

# Load dataset
df = pd.read_csv("/kaggle/input/threads-fake-news-dataset/NewThreadsData_Labeled.csv", encoding='ISO-8859-1')

# Ensure 'Post Text' column is string and handle missing values
df["Post Text"] = df["Post Text"].astype(str).fillna("")

# Initialize tokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

# Apply tokenizer safely
df["tokenized_text"] = df["Post Text"].apply(lambda x: tokenizer.encode(x, truncation=True, padding="max_length", max_length=128))

# Split data
train_texts, val_texts = train_test_split(df["tokenized_text"], test_size=0.2, random_state=42)

print("Tokenization successful!")

# %%
import torch.optim as optim
import torch.nn as nn
import torch

# Hyperparameters
vocab_size = len(tokenizer.vocab)  # Ensure tokenizer is defined
embedding_dim = 128
hidden_dim = 256
seq_length = 128
batch_size = 64
num_epochs = 10

# Define Generator and Discriminator classes
class Generator(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, seq_length):
        super(Generator, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, vocab_size)

    def forward(self, noise):
        embedded = self.embedding(noise)  # Shape: (batch_size, seq_length, embedding_dim)
        lstm_out, _ = self.lstm(embedded)  # Shape: (batch_size, seq_length, hidden_dim)
        logits = self.fc(lstm_out)  # Shape: (batch_size, seq_length, vocab_size)
        return logits  # Return logits, not softmaxed values

class Discriminator(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, seq_length):
        super(Discriminator, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, 1)  # Scalar output per sequence
        self.sigmoid = nn.Sigmoid()

    def forward(self, sequences):
        embedded = self.embedding(sequences)  # (batch_size, seq_length, embedding_dim)
        lstm_out, _ = self.lstm(embedded)  # (batch_size, seq_length, hidden_dim)
        logits = self.fc(lstm_out[:, -1, :])  # Use last hidden state
        return self.sigmoid(logits)  # Output a single probability for each sequence

# Initialize models and move to GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
generator = Generator(vocab_size, embedding_dim, hidden_dim, seq_length).to(device)
discriminator = Discriminator(vocab_size, embedding_dim, hidden_dim, seq_length).to(device)

# Optimizers
g_optimizer = optim.Adam(generator.parameters(), lr=0.0002)
d_optimizer = optim.Adam(discriminator.parameters(), lr=0.0002)

# Loss function
criterion = nn.BCELoss()

# Ensure train_texts is a properly formatted tensor
train_tensor = torch.tensor(train_texts.tolist(), dtype=torch.long, device=device)  # Convert list to tensor

# Training loop
for epoch in range(num_epochs):
    for i in range(0, len(train_tensor), batch_size):
        real_sequences = train_tensor[i:i + batch_size]
        batch_size_actual = real_sequences.shape[0]  # Get the actual batch size

        # Add small Gaussian noise to inputs to stabilize training
        real_sequences_float = real_sequences.float()  # Convert to float type
        real_sequences_noisy = real_sequences_float + 0.1 * torch.randn_like(real_sequences_float, device=device)
        fake_sequences = generator(torch.randint(0, vocab_size, (batch_size_actual, seq_length), dtype=torch.long, device=device))

        # Convert noisy sequences back to long type
        real_sequences_noisy = real_sequences_noisy.long()

        # Train Discriminator less often (every 3rd batch)
        if i % 3 == 0:
            real_labels = torch.ones(batch_size_actual, 1, device=device)  # Use actual batch size
            fake_labels = torch.zeros(batch_size_actual, 1, device=device)  # Use actual batch size

            d_real_loss = criterion(discriminator(real_sequences_noisy), real_labels)
            fake_sequence_indices = fake_sequences.argmax(dim=-1)  # Get token indices
            d_fake_loss = criterion(discriminator(fake_sequence_indices), fake_labels)  # Use indices here
            d_loss = d_real_loss + d_fake_loss

            d_optimizer.zero_grad()
            d_loss.backward()
            d_optimizer.step()

        # Train Generator more often (2 times per step)
        for _ in range(2):
            # Use the generator's output directly in the discriminator
            fake_sequence_indices = fake_sequences.argmax(dim=-1)  # Get token indices
            real_labels = torch.ones(batch_size_actual, 1, device=device)  # Use actual batch size
            g_loss = criterion(discriminator(fake_sequence_indices), real_labels)  # Use indices for loss

            g_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

    print(f"Epoch {epoch+1}/{num_epochs}, D Loss: {d_loss.item():.4f}, G Loss: {g_loss.item():.4f}")
# Out:
# Epoch 1/10, D Loss: 0.7643, G Loss: 0.6803
# Epoch 2/10, D Loss: 0.6645, G Loss: 0.7724
# Epoch 3/10, D Loss: 0.5002, G Loss: 1.0029
# Epoch 4/10, D Loss: 0.1963, G Loss: 3.2906
# Epoch 5/10, D Loss: 0.1291, G Loss: 3.3176
# Epoch 6/10, D Loss: 0.0769, G Loss: 3.7468
# Epoch 7/10, D Loss: 0.0787, G Loss: 4.0253
# Epoch 8/10, D Loss: 0.0712, G Loss: 4.0900
# Epoch 9/10, D Loss: 0.0617, G Loss: 4.1627
# Epoch 10/10, D Loss: 0.0648, G Loss: 4.1300

# %%
import torch

# Function to generate fake news with word count constraint
def generate_fake_news(generator, tokenizer, vocab_size, seq_length, num_samples, device, min_words=10, max_words=200):
    generated_articles = []
    
    while len(generated_articles) < num_samples:
        # Generate random noise
        noise = torch.randint(0, vocab_size, (1, seq_length), dtype=torch.long, device=device)

        # Generate fake text
        with torch.no_grad():
            fake_sequence = generator(noise)  # Shape: (1, seq_length, vocab_size)
        
        # Convert probabilities to token IDs
        token_ids = fake_sequence.argmax(dim=-1).squeeze(0)  # Shape: (seq_length,)

        # Decode token IDs to text
        generated_text = tokenizer.decode(token_ids.tolist())
        
        # Count words in generated text
        word_count = len(generated_text.split())

        # Keep only texts within the word count range
        if min_words <= word_count <= max_words:
            generated_articles.append(generated_text)

    return generated_articles

# Example usage
num_samples = 1000  # Number of fake news articles to generate
fake_news = generate_fake_news(generator, tokenizer, vocab_size, seq_length, num_samples, device)

# Print generated fake news
for idx, article in enumerate(fake_news):
    print(f"Fake News Article {idx+1} (Word Count: {len(article.split())}):")
    print(article)
    print("-" * 50)
# Out:
# Fake News Article 1 (Word Count: 103):
# --------------------------------------------------

# %%
import pandas as pd

# Load your existing dataset
# df = pd.read_csv("your_dataset.csv")

# Convert generated fake news into a DataFrame
fake_news_df = pd.DataFrame({
    "Post Text": fake_news,   # Generated fake news text
    "label": [1] * len(fake_news)  # Assign "1" for fake news
})

# Append synthetic data to the original dataset
df_augmented = pd.concat([df, fake_news_df], ignore_index=True)


print("Dataset augmented successfully! New size:", len(df_augmented))
# Out:
# Dataset augmented successfully! New size: 5213

# %%
df_augmented = df_augmented.drop(columns=['tokenized_text'])
# Save the new dataset
df_augmented.to_csv("augmented_dataset.csv", index=False)

# %% [markdown]
# # LLM To Generate Fake Data

# %% [markdown]
# ## Manipulate Existing Fake Data

# %% [markdown]
# ### 1 manipulate text for each original text

# %%
import pandas as pd
import torch
from transformers import T5Tokenizer, T5ForConditionalGeneration
from IPython.display import FileLink

# Load the dataset
dataset_path = "/kaggle/input/threads-fake-news-dataset/NewThreadsData_Labeled.csv"
df = pd.read_csv(dataset_path, encoding='ISO-8859-1')

# Ensure required columns exist
assert "Post Text" in df.columns and "label" in df.columns, "Dataset must have 'Post Text' and 'label' columns."

# Filter only fake news samples
fake_news_df = df[df['label'] == 1]["Post Text"].dropna().tolist()

# Load FLAN-T5 model and tokenizer
model_name = "google/flan-t5-base"
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name).to("cuda" if torch.cuda.is_available() else "cpu")

def generate_manipulated_fake_news(texts, num_variations=1):
    manipulated_samples = []
    for text in texts:
        prompt = f"Rewrite the following news post with slight manipulation: {text}"
        inputs = tokenizer(prompt, return_tensors="pt", max_length=512, truncation=True).to(model.device)
        
        # Generate new text
        with torch.no_grad():
            outputs = model.generate(**inputs, max_length=512, num_return_sequences=num_variations, temperature=0.8)
        
        # Decode and store
        for output in outputs:
            manipulated_text = tokenizer.decode(output, skip_special_tokens=True)
            manipulated_samples.append((text, manipulated_text))  # Store both original and manipulated

    return manipulated_samples

# Generate manipulated fake news
num_samples_needed = 1000  # Balance the dataset
num_samples_to_generate = min(1000, len(fake_news_df))  # Ensure we don't exceed available samples
selected_fake_news = fake_news_df[:num_samples_to_generate]
manipulated_fake_news_pairs = generate_manipulated_fake_news(selected_fake_news)

# Print some original vs manipulated fake news examples
print("\nSample Manipulated Fake News:")
for i in range(5):  # Print first 5 examples
    original, manipulated = manipulated_fake_news_pairs[i]
    print(f"Original: {original}\nManipulated: {manipulated}\n{'-'*80}")

# Create a new DataFrame with manipulated fake news
new_fake_news_df = pd.DataFrame({"Post Text": [pair[1] for pair in manipulated_fake_news_pairs], "label": 1})

# Merge with the original dataset
df = pd.concat([df, new_fake_news_df], ignore_index=True)

# Shuffle dataset
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# Save the balanced dataset
balanced_dataset_path = "balanced_dataset_withLLM.csv"
df.to_csv(balanced_dataset_path, index=False)
print(f"\nBalanced dataset saved at {balanced_dataset_path}")

# Provide download link in Kaggle notebook
print("\nClick below to download the dataset:")
display(FileLink(balanced_dataset_path))
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:628: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.8` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Sample Manipulated Fake News:
# Original: Revelation 6:12: An earthquake will occur before the seventh seal, also known as the "day of the LORD"This happen Wednesday!
# Manipulated: Revelation 6:12: An earthquake will occur before the seventh seal, also known as the "day of the LORD" This happen Wednesday!
# --------------------------------------------------------------------------------
# Original: RumorÃ°ÂÂÂ¨: Governor Gavin Newsome is considering plans to secede from the Union in order to prevent Trump from deporting illegal  aliens and implementing Voter ID laws.
# How do you think California would do on her own?
# Manipulated: California is considering a plan to secede from the Union in order to prevent Trump from deporting illegal aliens and implementing Voter ID laws. How do you think California would do on her own?
# --------------------------------------------------------------------------------
# Original: If true, doesnÃ¢ÂÂt look like anyone from our side.
# Manipulated: Is it true that he looks like someone from our side?
# --------------------------------------------------------------------------------
# Original: BREAKING NEWS: Megyn Kelly calls for boycott of Taylor Swift after singer attends charity event in Gaza. Taylor said: "I don't have to explain what I do, you talk like a...." See more
# buff.ly/3zWlqÃ¢ÂÂ¦
# Manipulated: Megyn Kelly called for a boycott of Taylor Swift after the singer attended a charity event in Gaza. Taylor Swift said: "I don't have to explain what I do, you talk like a...
# --------------------------------------------------------------------------------
# Original: so all men (18-26) have been automatically registered in the US ARMY ???? this is INSANE!
# Manipulated: i think i'm gonna be a shithole.
# --------------------------------------------------------------------------------
#
# Balanced dataset saved at balanced_dataset_withLLM.csv
#
# Click below to download the dataset:
# /kaggle/working/balanced_dataset_withLLM.csv

# %% [markdown]
# ### 3 manipulate text for each original text

# %%
import pandas as pd
import torch
from transformers import T5Tokenizer, T5ForConditionalGeneration
from IPython.display import FileLink

# Load the dataset
dataset_path = "/kaggle/input/threads-fake-news-dataset/NewThreadsData_Labeled.csv"
df = pd.read_csv(dataset_path, encoding='ISO-8859-1')

# Ensure required columns exist
assert "Post Text" in df.columns and "label" in df.columns, "Dataset must have 'Post Text' and 'label' columns."

# Filter only fake news samples
fake_news_df = df[df['label'] == 1]["Post Text"].dropna().tolist()

# Load FLAN-T5 model and tokenizer
model_name = "google/flan-t5-base"
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name).to("cuda" if torch.cuda.is_available() else "cpu")

def generate_manipulated_fake_news(texts, num_variations=3):
    manipulated_samples = []
    for text in texts:
        prompt = f"Rewrite the following news post with slight manipulation: {text}"
        inputs = tokenizer(prompt, return_tensors="pt", max_length=512, truncation=True).to(model.device)
        
        # Generate 3 variations per original text
        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_length=512,
                num_return_sequences=num_variations,  # Generate 3 versions
                temperature=0.8,
                do_sample=True
            )

        # Decode and store multiple variations
        for output in outputs:
            manipulated_text = tokenizer.decode(output, skip_special_tokens=True)
            manipulated_samples.append((text, manipulated_text))  # Store both original and manipulated

    return manipulated_samples

# Generate manipulated fake news (with 3 variations per original)
num_samples_needed = 1500
num_samples_to_generate = min(1500, len(fake_news_df))  # Ensure we don't exceed available samples
selected_fake_news = fake_news_df[:num_samples_to_generate]
manipulated_fake_news_pairs = generate_manipulated_fake_news(selected_fake_news, num_variations=3)

# Print some original vs manipulated fake news examples
print("\nSample Manipulated Fake News:")
for i in range(5):  # Print first 5 sets of variations
    original = manipulated_fake_news_pairs[i * 3][0]  # Original text
    variations = [manipulated_fake_news_pairs[i * 3 + j][1] for j in range(3)]  # Get 3 variations
    print(f"Original: {original}")
    for idx, variant in enumerate(variations, 1):
        print(f"Variation {idx}: {variant}")
    print("-" * 80)

# Create a new DataFrame with all manipulated fake news
new_fake_news_df = pd.DataFrame({"Post Text": [pair[1] for pair in manipulated_fake_news_pairs], "label": 1})

# Merge with the original dataset
df = pd.concat([df, new_fake_news_df], ignore_index=True)

# Shuffle dataset
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# Save the balanced dataset
balanced_dataset_path = "balanced_dataset_withLLM2.csv"
df.to_csv(balanced_dataset_path, index=False)
print(f"\nBalanced dataset saved at {balanced_dataset_path}")

# Provide download link in Kaggle notebook
print("\nClick below to download the dataset:")
display(FileLink(balanced_dataset_path))
# Out:
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Sample Manipulated Fake News:
# Original: Revelation 6:12: An earthquake will occur before the seventh seal, also known as the "day of the LORD"This happen Wednesday!
# Variation 1: The earthquake will occur before the seventh seal.
# Variation 2: An earthquake will occur ahead of the seventh seal. This happens Wednesday!
# Variation 3: The earthquake that will occur tomorrow will happen before the seventh seal.
# --------------------------------------------------------------------------------
# Original: RumorÃ°ÂÂÂ¨: Governor Gavin Newsome is considering plans to secede from the Union in order to prevent Trump from deporting illegal  aliens and implementing Voter ID laws.
# How do you think California would do on her own?
# Variation 1: California is considering deporting illegal aliens and implementing Voter ID laws... Why would she?
# Variation 2: The Governor of California is considering a vote to seize control of the US from the Trump administration, but there's a chance he'll skip it.
# Variation 3: Californians have sunk a hole in their necks about how they would move to the United States in the future. They are now asking, why will it be a hard choice?
# --------------------------------------------------------------------------------
# Original: If true, doesnÃ¢ÂÂt look like anyone from our side.
# Variation 1: When you look at that picture of a person with the same name, it makes no sense at all.
# Variation 2: I think we found a "do not mess" story.
# Variation 3: Don’t do this! Don’t do this! Don’t do this! Don’t tell anyone!
# --------------------------------------------------------------------------------
# Original: BREAKING NEWS: Megyn Kelly calls for boycott of Taylor Swift after singer attends charity event in Gaza. Taylor said: "I don't have to explain what I do, you talk like a...." See more
# buff.ly/3zWlqÃ¢ÂÂ¦
# Variation 1: Megyn Kelly is calling for a boycott of Taylor Swift after a charity event in Gaza. The singer reportedly left the Gaza Strip on his way to mark his birthday. "I'd rather not be here, I want to make people aware of that... I've got to go home ... I can't go. Let people know their love for him," she told CNN. "My mom just loves her, she loves you and everybody loves her. You can't go home." Taylor, a Grammy-nominated American, is due to perform on Friday at a concert in Israel. The singer has asked the US to boycott her. "I don't have to explain what I do, you talk like a..." she said.
# Variation 2: Megyn Kelly is calling for a boycott when she attends an event in Gaza on Monday, following the singer's cancellation of her concert.
# Variation 3: Megyn Kelly voted for a boycott of Taylor Swift after the singer attended a charity event in Gaza. Taylor Swift said: "I'm sorry that I can't have to explain what I do, you talk like a...." (VIDEO) The singer also addressed the protest of his death at the UN-Gaza conference, following the suicide attack on the UN compound in Gaza.
# --------------------------------------------------------------------------------
# Original: so all men (18-26) have been automatically registered in the US ARMY ???? this is INSANE!
# Variation 1: Just a quick note, as a former soldier in the armed forces, I must admit, there is a line of fire that will keep you from submitting an application to the US Army. Is that a pity?
# Variation 2: The US Army has approved the automatic registration of all men (18-26) in the US armed forces. Is this a "new law" or the beginning of "automatic registration"?
# Variation 3: How has this happened?
# --------------------------------------------------------------------------------
#
# Balanced dataset saved at balanced_dataset_withLLM.csv
#
# Click below to download the dataset:
# /kaggle/working/balanced_dataset_withLLM.csv

# %%
import pandas as pd
import torch
from transformers import T5Tokenizer, T5ForConditionalGeneration
from IPython.display import FileLink

# Load the dataset
dataset_path = "/kaggle/input/cleaned-dataset/Cleaned_NewThreadsData_Labeled.csv"
df = pd.read_csv(dataset_path, encoding='ISO-8859-1')

# Ensure required columns exist
assert "Post Text" in df.columns and "label" in df.columns, "Dataset must have 'Post Text' and 'label' columns."

# Filter only fake news samples
fake_news_df = df[df['label'] == 1]["Post Text"].dropna().tolist()

# Load FLAN-T5 model and tokenizer
model_name = "google/flan-t5-base"
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name).to("cuda" if torch.cuda.is_available() else "cpu")

def generate_manipulated_fake_news(texts, num_variations=3):
    manipulated_samples = []
    for text in texts:
        prompt = f"Rewrite the following news post while keeping the meaning unchanged but modifying phrasing and word order slightly: {text}"
        inputs = tokenizer(prompt, return_tensors="pt", max_length=512, truncation=True).to(model.device)
        
        # Generate 3 variations per original text
        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_length=512,
                num_return_sequences=num_variations,  # Generate 3 versions
                temperature=0.8,
                do_sample=True
            )

        # Decode and store multiple variations
        for output in outputs:
            manipulated_text = tokenizer.decode(output, skip_special_tokens=True)
            manipulated_samples.append((text, manipulated_text))  # Store both original and manipulated

    return manipulated_samples

# Generate manipulated fake news (with 3 variations per original)
num_samples_needed = 1500
num_samples_to_generate = min(1500, len(fake_news_df))  # Ensure we don't exceed available samples
selected_fake_news = fake_news_df[:num_samples_to_generate]
manipulated_fake_news_pairs = generate_manipulated_fake_news(selected_fake_news, num_variations=3)

# Print some original vs manipulated fake news examples
print("\nSample Manipulated Fake News:")
for i in range(10):  # Print first 10 sets of variations
    original = manipulated_fake_news_pairs[i * 3][0]  # Original text
    variations = [manipulated_fake_news_pairs[i * 3 + j][1] for j in range(3)]  # Get 3 variations
    print(f"Original: {original}")
    for idx, variant in enumerate(variations, 1):
        print(f"Variation {idx}: {variant}")
    print("-" * 80)

# Create a new DataFrame with all manipulated fake news
new_fake_news_df = pd.DataFrame({"Post Text": [pair[1] for pair in manipulated_fake_news_pairs], "label": 1})

# Merge with the original dataset
df = pd.concat([df, new_fake_news_df], ignore_index=True)

# Shuffle dataset
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# Save the balanced dataset
balanced_dataset_path = "balanced_dataset_withLLM3.csv"
df.to_csv(balanced_dataset_path, index=False)
print(f"\nBalanced dataset saved at {balanced_dataset_path}")

# Provide download link in Kaggle notebook
print("\nClick below to download the dataset:")
display(FileLink(balanced_dataset_path))
# Out:
# Sample Manipulated Fake News:
# Original: BREAKING  Vice President JD Vances wife will have her citizenship revoked if Trump signs his executive order banning birthright citizenship Neither of her parents were US citizens at the time of her birth
# Variation 1: Trump's executive order bans "birthright citizenship" and "candidate law."
# Variation 2: BREAKING Vice President JD Vances wife will have her citizenship revoked if Trump signs his executive order banning birthright citizenship. Neither of her parents were US citizens at the time of her birth...
# Variation 3: BREAKING VP J.D. Vances wife will have her citizenship revoked if Trump signs his executive order banning birthright citizenship. Neither of her parents were US citizens at the time of her birth. Neither of her parents were US citizens at the time of her birth.
# --------------------------------------------------------------------------------
# Original: Breaking News
# New sunrise of educationClass 2021 to Saturday Friday is a full holiday
# Variation 1: New sunrise of educationClass 2021 to Saturday Friday is a full holiday
# Variation 2: New sunrise of educationClass 2021-Sunday November 30th is a full holidays
# Variation 3: New sunrise of educationClass 2021 to Saturday Friday is a full holiday
# --------------------------------------------------------------------------------
# Original: BREAKING Donald Trump has nominated Amber Rose for Secretary of Education
# Variation 1: Donald Trump has nominated Amber Rose for Secretary of Education, his new high-profile job.
# Variation 2: Trump has nominated Amber Rose as Secretary of Education.
# Variation 3: Donald Trump nominated Amber Rose for Secretary of Education
# --------------------------------------------------------------------------------
# Original: Elon Musk Reportedly Eyeing CNN Acquisition Fix the Media One Network at a Time
# Variation 1: Elon Musk, the former CEO of CNN, may have already hailed the CNN purchase. But despite it, the deal isn’t quite done. After the alleged acquisition of CNN, Elon Musk is eyeing a possible cable deal to make access to CNN a priority.
# Variation 2: Elon Musk Reportedly Looking for CNN Acquisition Fix the Media One Network at a Time
# Variation 3: Elon Musk Reportedly Eyeing CNN Acquisition Fix the Media One Network at a Time
# --------------------------------------------------------------------------------
# Original: Current bills of all mosques and madrasas are free from September 7
# Dr Yunus
# Variation 1: A total of 389 mosques and madrasas are free under the current bill of Rs. 3 a year from September 7, Dr Yunus says.
# Variation 2: Current bills of all mosques and madrasas are free from September 7, he added
# Variation 3: Current bills of all mosques and madrasas are free from September 7 Dr Yunus
# --------------------------------------------------------------------------------
# Original: Away days ahead On December 14 GKFC vs Shillong Lajong FCgkfc malabarians ILeague Indianfootball gokulamkeralafc gkfccbfc
# Variation 1: On December 14, GKFC vs Shillong Lajong FCgkfc malabarians ILeague Indianfootball gokulamkeralafc gkfccbfc
# Variation 2: Away days ahead On December 14 GKFC vs Shillong Lajong FCgkfc malabarians ILeague Indianfootball gokulamkerala fc
# Variation 3: Away days ahead On December 14 GKFC vs Shillong Lajong FCgkfc malabarians ILeague Indianfootball gokulamkeralafc gkfccbfc
# --------------------------------------------------------------------------------
# Original: TCBs 1 lakh cards have been canceled Didnt you think of 1 million families
# Variation 1: TCBs 1 lakh cards have been canceled Didnt you think of 1 million families?
# Variation 2: TCBs 1 lakh cards have been canceled Didnt you think of 1 million families?
# Variation 3: TCBs 1 lakh cards are canceled. Didnt you think of 1 million families?
# --------------------------------------------------------------------------------
# Original: What a great laugh to start out my morning know I said this in 2016 but this time I really mean it
# So is he saying he didnt mean it in 2016 This is what abusers say to their victims after they have beat them and want you to trust them again Thats a big no
# Variation 1: One morning bjcdns I saw these words in 2016 but this time I really meant it. Is he saying he didnt mean it in 2016? What is abusers saying to their victims after they have beat them and want you to trust them again? Thats a big no,
# Variation 2: One thing I like about the new movie is the fact that it was not the same movie that he and his wife had been in since.
# Variation 3: I am sorry to say this (see my previous comments) It was extremely disturbing and made me feel very uncomfortable.
# --------------------------------------------------------------------------------
# Original: ROBOTS PARA EL EMBARAZO
# Corren rumores en donde se dice que Elon Musk est trabajando en un robot diseado para llevar un beb durante nueve meses supuestamente para liberar a los paps de los retos sicos del embarazoSiendo as  las parejas solo tendran que aportar el esperma y los vulos y el robot se encargara de nutrir al embrin hasta el nacimientoSe respalda esta idea diciendo que la tecnologa podra reducir much simo los riesgos que enfrentan las mujeres al dar a luz
# Variation 1: Corren rumores en donde se dice que Elon Musk es trabajando en un robot de diseo de cerca de nueve meses adecuadamente para liberar a los paps de los sicos del embarazoSiendo as las parejas solo tendran que aportar el sperma y los vislos y el robot se entregara en alimentos al embrinto hasta el nacimientoSe respalda este idea diciendo que la tecnologa puede reducir mucho miedo los riesgos que enfrentan las mujeres a dar a luz
# Variation 2: Corren rumores en donde se dice que Elon Musk está trabajando en un robot diseado para llevar un beb durante nueve meses supuestamente para liberar las papeles de las sicos retos del embajo.Se respalda esta idea diciendo que la tecnologa podrá reducir muchos miedos los riesgos que enfrentan las mujeres a dar a luz
# Variation 3: Corren rumores en donde se dice que Elon Musk está trabajando en un robot diseado para llevar un bb durante nueve meses sobre sicos relacionadas para liberar los paps de los problemas sicos del embarazo.Siendo as las parejas solo tendran que aportar esperma y los vulos y el robot se encargara para nutrir a embrinto hasta la nueva nacimientoSe respalda esta idea diciendo que la tecnologa puede reducir muchos los riesgos que enfrentan las mujeres a dar a luz.
# --------------------------------------------------------------------------------
# Original: Im pretty sure covid and the lockdowns showed us who the truly essential workers are and it isnt CEOs
# I worked in member services for a health ins company many years ago and could tell stories I had members die while I tried to get treatment approved for them It doesnt seem to have improved since then We were told that our job was to make money for the shareholders and not taking care of our members
# Variation 1: Covid and the lockdowns showed us who the truly essential workers are and it isnt CEOs.
# Variation 2: Is this really the key to our health? I'm pretty sure covid and the lockdowns showed us who the truly essential workers are and it isn't CEOs
# Variation 3: I'm pretty sure covid and the lockdowns showed us who the truly essential workers are and it isnt CEOs. I worked in member services for a health ins company many years ago and could tell stories I had members die while I tried to get treatment approved for them It doesnt seem to have improved since then. We were told that our job was to make money for the shareholders and not taking care of our members. I guess that's what the CEO job is for the employees.
# --------------------------------------------------------------------------------
#
# Balanced dataset saved at balanced_dataset_withLLM3.csv
#
# Click below to download the dataset:
# /kaggle/working/balanced_dataset_withLLM3.csv

# %%
import pandas as pd
import torch
from transformers import T5Tokenizer, T5ForConditionalGeneration
from IPython.display import FileLink

# Load the dataset
dataset_path = "/kaggle/input/cleaned-dataset/Cleaned_NewThreadsData_Labeled.csv"
df = pd.read_csv(dataset_path, encoding='ISO-8859-1')

# Ensure required columns exist
assert "Post Text" in df.columns and "label" in df.columns, "Dataset must have 'Post Text' and 'label' columns."

# Filter only fake news samples
fake_news_df = df[df['label'] == 1]["Post Text"].dropna().tolist()

# Load T5-Large model and tokenizer
model_name = "t5-large"
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name).to("cuda" if torch.cuda.is_available() else "cpu")

def generate_manipulated_fake_news(texts, num_variations=3):
    manipulated_samples = []
    for text in texts:
        # Improved prompt to encourage slight modification while preserving meaning
        prompt = f"Paraphrase the following news post while keeping its meaning intact. Make slight word and phrasing changes: {text}"
        inputs = tokenizer(prompt, return_tensors="pt", max_length=512, truncation=True).to(model.device)
        
        # Generate 3 variations per original text
        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_length=512,
                num_return_sequences=num_variations,  # Generate 3 versions
                temperature=0.7,   # Moderate randomness
                top_k=50,          # Top 50 token choices for better variation
                top_p=0.95,        # Nucleus sampling to avoid extreme changes
                do_sample=True
            )

        # Decode and store multiple variations
        for output in outputs:
            manipulated_text = tokenizer.decode(output, skip_special_tokens=True)
            manipulated_samples.append((text, manipulated_text))  # Store both original and manipulated

    return manipulated_samples

# Generate manipulated fake news (with 3 variations per original)
num_samples_needed = 1500
num_samples_to_generate = 1500  # Ensure we don't exceed available samples
selected_fake_news = fake_news_df[:num_samples_to_generate]
manipulated_fake_news_pairs = generate_manipulated_fake_news(selected_fake_news, num_variations=3)

# Print some original vs manipulated fake news examples
print("\nSample Manipulated Fake News:")
for i in range(10):  # Print first 10 sets of variations
    original = manipulated_fake_news_pairs[i * 3][0]  # Original text
    variations = [manipulated_fake_news_pairs[i * 3 + j][1] for j in range(3)]  # Get 3 variations
    print(f"Original: {original}")
    for idx, variant in enumerate(variations, 1):
        print(f"Variation {idx}: {variant}")
    print("-" * 80)

# Create a new DataFrame with all manipulated fake news
new_fake_news_df = pd.DataFrame({"Post Text": [pair[1] for pair in manipulated_fake_news_pairs], "label": 1})

# Merge with the original dataset
df = pd.concat([df, new_fake_news_df], ignore_index=True)

# Shuffle dataset
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# Save the balanced dataset
balanced_dataset_path = "balanced_dataset_with_T5Large.csv"
df.to_csv(balanced_dataset_path, index=False)
print(f"\nBalanced dataset saved at {balanced_dataset_path}")

# Provide download link in Kaggle notebook
print("\nClick below to download the dataset:")
display(FileLink(balanced_dataset_path))
# Out:
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# --------------------------------------------------------------------------------
# Original: Elon Musk Reportedly Eyeing CNN Acquisition Fix the Media One Network at a Time
# Variation 1: : Elon Musk Eyes CNN Acquisition Fix the Media One Network at a Time:: Fix the Media: Elon Musk Eyes CNN Acquisition Fix the Media One Network at a Time: Fix the Media One Network at a Time: Fix the Media One Network at a Time: Fix the Media: Fix the Media One Network at a Time Fix Media Media Fix the Media Network Fix the Media Time Fix media.:: Elon Musk CNN
# Variation 2: : Elon Musk Eyeing CNN Acquisition Fix the Media One Network at a Time:: Elon Musk Fix the Media One Network at a Time: Elon Musk Eyes CNN Acquisition Fix the Media One Network at a Time: Fix the Media One Network at a Time Fix the Media Fix the Media Fix the Media Fix the Media News CNN CNN News and.::::::.::
# Variation 3: Elon Musk Eyeing CNN Acquisition Elon Musk Eyeing CNN Acquisition Fix the Media One Network at a Time Fix the Media by Rephrasing the following news post: Elon Musk Elon Musk Fix the Media One Network at a Time Fix the Media One Network at a Time Fix the Media One Network at a Time Fix the Media: Fix the Media ...:::..::.:::: Fix the Media
# --------------------------------------------------------------------------------
# Original: Current bills of all mosques and madrasas are free from September 7
# Dr Yunus
# Variation 1: of all mosques and madrasas are free from September 7 : Current bills of all mosques and madrasas are and. Current bills of all mosques and madrasas are free from September 7 and and The. To: to: Change.::: Make slight word and phrasing changes::::: Make:::..: All:
# Variation 2: of all mosques and madrasas are free from September 7: Current bills of all mosques and madrasas are free from September 7 and: Current bills of all mosques and madrasas are free from September 7 Dr. The and and Free......::::: Make slight::: This: free: Current: Current bills of: bin
# Variation 3: of all mosques and madrasas will be free from September 7: All current bills of all mosques and madrasas are and and all their children are free from September 7 All current bills of all mosques and madrasas are free and of all mosques and madrasa and and..: and..::::::::
# --------------------------------------------------------------------------------
# Original: Away days ahead On December 14 GKFC vs Shillong Lajong FCgkfc malabarians ILeague Indianfootball gokulamkeralafc gkfccbfc
# Variation 1: mmalabarians ILeague Indianfootball gkfccbfc malabarians ILeague Indianfootball gokulamkeralafcaafcgkfccbfc sl slajongfc. GKFC news and::::bfcgope.mcc.dc
# Variation 2: Gokulamkerala gkfc gkfccbfc gkfc kfc gkfccbfc gkfccbfc gkfcgkfc vs vs : Make:.::.. . . gkfcch
# Variation 3: gokulamkeralafc malabarians ILeague Indianfootball gokulamkeralafccbfcbfccbfcgkfcgkfc gkfccbfc gkfccbfcc vsgk vs vsm::::::. gcg c
# --------------------------------------------------------------------------------
# Original: TCBs 1 lakh cards have been canceled Didnt you think of 1 million families
# Variation 1: whose card is cancelled. of TCB members whose TCB credit cards are canceled whose TCB cards were cancelled ? They are canceled after TCBs decision to cancel whose cards have been cancelled. who have no credit cards:: 1 lakh cards have been canceled::::::::::: changes:: affected affected affectedwhose.? TC
# Variation 2: whose cards have been canceled. whose cards have been cancelledwhose cards were canceled? TCBs 1 lakh cards have been canceled whose cards were canceled. Did you think of 1 million families whose cards have been canceled. Did you think of 1 million families whose cards have been canceled. If you think whosed affected.::::::::::::.
